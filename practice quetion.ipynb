# %%
# Calculate the multiplication and sum of two numbers
 # Given two integer numbers, write a Python program to return their product only
 if the product is equal to or lower than 1000. Otherwise, return their sum.

# %%
num1 = int(input("enter the 1st number"))
num2 = int(input("enter the 2nd number"))

num3 = num1*num2
if(num3 <= 1000):
     print(num3)
else:
    print(num1+num2)
# Out:
# enter the 1st number 20
# enter the 2nd number 30
# 600

# %%
#Write a code to return True if the list’s first and last numbers are the same. If the numbers are different, return False.

# %%
list1 = (input("enter your list "))

first_num = list1[0]
last_num = list1[-1]

if (first_num == last_num):
   print(True)
else:
   print(False)
# Out:
# enter your list  11, 12, 14 , 55
# False

# %%
# Write a Python code to display numbers from a list divisible by 5

# %%
list2 = [ 5, 10 , 12 , 15 , 20 ,25, 27, 30]
print("given list :", list2)
print("divisible by 5:")
for num in list2:
   if num % 5 == 0:
       print(num)
# Out:
# given list : [5, 10, 12, 15, 20, 25, 27, 30]
# divisible by 5:
# 5
# 10
# 15
# 20
# 25
# 30

# %%
num_list = [10, 20, 33, 46, 55]
print("Given list:", num_list)
print('Divisible by 5:')
for num in num_list:
    if num % 5 == 0:
        print(num)

# %% [markdown]
# # *29-09-2025*

# %%
age =int(input("age="))

#nesting
if(age >=18):
    if(age>=80):
        print("cannot drive")
    else:
        print("can drive")
else:
    print("cannot drive")
# Out:
# age= 99
# cannot drive

# %% [markdown]
#  1 WAP to check if a number entered by the user is odd or even

# %%
num = int(input("enter number"))

if(num % 2 == 0):
    print ("it is a even number")

else:
    print("it is a odd number")
# Out:
# enter number 11
# it is a odd number

# %% [markdown]
#  2 WAP to find the greatest of 3 number entered by user

# %%
num1 = int(input("enter number:"))
num2 = int(input("enter number:"))
num3 = int(input("enter number:"))
if(num1>=num2 and num1>=num3):
    print("num1 is greatest" , num1)
elif(num2>=num3):
    print("num2 is greatest", num2)
else:
    print("num3 is greatest", num3)

# %%
 A= int(input("enter  first number:"))
 B = int(input("enter  second number:"))
 C = int(input("enter  third number:"))

if(A>=B and A>=C):
   print("first number is greatest" , A)
elif(B >= C):
   print("second num is greatest" , B)
else:
   print("third num is greater:", C)
# Out:
# enter  first number: 11
# enter  second number: 12
# enter  third number: 13
# third num is greater: 13

# %% [markdown]
#  3 WAP to check if a number is multiple of 7 or not

# %%
num1 = int(input("enter a number"))

if(num1 % 7 == 0):
    print("it is a multiple of 7")
else:
    print("it is not a multiple of 7")
# Out:
# enter a number 12567
# it is not a multiple of 7

# %% [markdown]
# #  *tuples and list*

# %% [markdown]
# # *list in python*
#
#   it is a built-in data type that stores set of values
#   it can store element of different types (integer , float, string , etc)

# %%
list1= [ 23, 24 , 65, 34 , 35, 26, 46 ,99, 76, 56,]
print(list1[2])
# Out:
# 65

# %%
l1 =  [ 1, 2, 3, 4]
l1.append(9)

# %%
l1.sort(reverse=True)
print(l1)
# Out:
# [9, 4, 3, 2, 1]

# %% [markdown]
# list methods
#
# list.append(4)  #add one element at the end
# list.sort()     # sorts in ascending order
# list.sort(reverse=True) # sort in decending order
# list.reverse()   #reverses the list
# list.insert(idx , el)  # insert element at index

# %%
list1.index(1, 98)
list1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 list1.index(1, 98)
#       2 list1
#
# ValueError: 1 is not in list

# %%
list1
# Out:
# [23, 24, 65, 34, 35, 26, 46, 99, 76, 56]

# %%
list1.index(23)
# Out:
# 0

# %%
list1.index()

# %%
num = int(input("enter number"))

if(num % 2 == 0):
    print ("it is a even number")

else:
    print("it is a odd number")
# Out:
# enter number 234
# it is a even number

# %%
num = int(input("Enter a number: "))

flag = False
if num == 0 or num ==1:
    print("is not a prime num" , num)
elif num>1:
    for i in range(2, num):
         if(num % i ) == 0:
         flag = True
         break
if flag:
    print("is not a prime number" , num)
else:
    print("is a prime number" , num)
# Out:
#   Cell In[98], line 9
#     flag = True
#     ^
# IndentationError: expected an indented block after 'if' statement on line 8
