# %%
String 
1 indexing
2. slicing 
3. Concatination
4. Repetation
5. mutation
6. Function

# %%
var1 = "this is my string"
print(var1)
# Out:
# this is my string

# %%
var2 = "this is my second string"
print(var2)
# Out:
# this is my second string

# %%
var1
# Out:
# 'this is my string'

# %%
var2
# Out:
# 'this is my second string'

# %%
var1.lower()
# Out:
# 'this is my string'

# %%
var1.capitalize()
# Out:
# 'This is my string'

# %%
var1.title()
# Out:
# 'This Is My String'

# %%
var1.isupper()
# Out:
# False

# %%
var1.islower()
# Out:
# True

# %%
var1.index("g")
# Out:
# 16

# %%
var1
# Out:
# 'this is my string'

# %%
var1.split()
# Out:
# ['this', 'is', 'my', 'string']

# %%
var1.split("i")
# Out:
# ['th', 's ', 's my str', 'ng']

# %%
"-".join(var1)
# Out:
# 't-h-i-s- -i-s- -m-y- -s-t-r-i-n-g'

# %%
var1.replace("t", "T")
# Out:
# 'This is my sTring'

# %%
var3= var1.replace("t", "T")

# %%
var3
# Out:
# 'This is my sTring'

# %%
var3.swapcase()
# Out:
# 'tHIS IS MY StRING'

# %%
# Concatination

# %%
var1  + " "+var2
# Out:
# 'this is my string this is my second string'

# %%
# Reperation

var1*2
# Out:
# 'this is my stringthis is my string'

# %%
# mutation

var1
# Out:
# 'this is my string'

# %%
var1[3]
# Out:
# 's'

# %%
# Function
var1
# Out:
# 'this is my string'

# %%
var3= var1.upper()

# %%
var3
# Out:
# 'THIS IS MY STRING'

# %%
var1.lower()
# Out:
# 'this is my string'

# %%
var1
# Out:
# 'this is my string'

# %%
var1.capitalize()
# Out:
# 'This is my string'

# %%
var1.title()
# Out:
# 'This Is My String'

# %%
var1.islower()
# Out:
# True

# %%
var1.isupper()
# Out:
# False

# %%
var3
# Out:
# 'THIS IS MY STRING'

# %%
var1.center(100)
# Out:
# '                                         this is my string                                          '

# %%
var1.count("t")
# Out:
# 2

# %%
var1.endswith("t")
# Out:
# False

# %%
var1.endswith("g")
# Out:
# True

# %%
var1.count("t")
# Out:
# 2

# %%
var1
# Out:
# 'this is my string'

# %%
var1.isnumeric()
# Out:
# False

# %%
"12345".isnumeric()
# Out:
# True

# %%
"1235649".isdecimal()
# Out:
# True

# %%
"1234234".isalpha()
# Out:
# False

# %%
var1.isalpha()
# Out:
# False

# %%
var1
# Out:
# 'this is my string'

# %%
"python".isalpha()
# Out:
# True

# %%
"df  ".isspace()
# Out:
# False

# %%
var1.index("i")
# Out:
# 2

# %%
var1
# Out:
# 'this is my string'

# %%
var1.partition(" ")
# Out:
# ('this', ' ', 'is my string')

# %%
var1.rpartition(" ")
# Out:
# ('this is my', ' ', 'string')

# %%
var1.split()
# Out:
# ['this', 'is', 'my', 'string']

# %%
var1.split("i")
# Out:
# ['th', 's ', 's my str', 'ng']

# %%
slist = var1.split("i")

# %%
slist
# Out:
# ['th', 's ', 's my str', 'ng']

# %%
"@".join(slist)
# Out:
# 'th@s @s my str@ng'

# %%
fruits = [ "Apple", "Banana", "Mango", "Orange", "Grapes", 
    "Pineapple", "Watermelon", "Papaya", "Guava", "Pomegranate",
    "Lemon", "Lime", "Sweet Lime", "Grapefruit", "Peach"]

# %%
"_".join(fruits)
# Out:
# 'Apple_Banana_Mango_Orange_Grapes_Pineapple_Watermelon_Papaya_Guava_Pomegranate_Lemon_Lime_Sweet Lime_Grapefruit_Peach'

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Mango',
#  'Orange',
#  'Grapes',
#  'Pineapple',
#  'Watermelon',
#  'Papaya',
#  'Guava',
#  'Pomegranate',
#  'Lemon',
#  'Lime',
#  'Sweet Lime',
#  'Grapefruit',
#  'Peach']

# %%
"-".join(fruits)
# Out:
# 'Apple-Banana-Mango-Orange-Grapes-Pineapple-Watermelon-Papaya-Guava-Pomegranate-Lemon-Lime-Sweet Lime-Grapefruit-Peach'

# %%
var1
# Out:
# 'this is my string'

# %% [raw]
# Remove prefix

# %%
var1.removeprefix("this")
# Out:
# ' is my string'

# %%
str1 = var1.replace("t" , "T")

# %%
str1
# Out:
# 'This is my sTring'

# %%
v1 = "   string  "

# %%
v1
# Out:
# '   string  '

# %%
v1.rstrip()
# Out:
# '   string'

# %%
v1.lstrip()
# Out:
# 'string  '

# %%
v1.strip()
# Out:
# 'string'

# %%
v2= "string&$$$$$"

# %%
v2
# Out:
# 'string&$$$$$'

# %%
v2.rstrip("&")
# Out:
# 'string&$$$$$'

# %%
v2.replace("&" , "")
# Out:
# 'string$$$$$'

# %%
v2.replace("&$", "")
# Out:
# 'string$$$$'

# %%
v2.rstrip("&$")
# Out:
# 'string'

# %% [raw]
# List

# %%
my_list = [ 11 , 12, 24,44, 45, 67, 78, ]

# %%
l1 = my_list

# %% [markdown]
# #26-09-2025

# %%
l1
# Out:
# [11, 12, 24, 44, 45, 67, 78]

# %%
l1.pop()
# Out:
# 78

# %%
l1
# Out:
# [12, 44, 45, 67]

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Mango',
#  'Orange',
#  'Grapes',
#  'Pineapple',
#  'Watermelon',
#  'Papaya',
#  'Guava',
#  'Pomegranate',
#  'Lemon',
#  'Lime',
#  'Sweet Lime',
#  'Grapefruit',
#  'Peach']

# %%
list[fruits]
# Out:
# list[['Apple', 'Banana', 'Mango', 'Orange', 'Grapes', 'Pineapple', 'Watermelon', 'Papaya', 'Guava', 'Pomegranate', 'Lemon', 'Lime', 'Sweet Lime', 'Grapefruit', 'Peach']]

# %%
l1
# Out:
# [11, 12, 24, 44, 45, 67, 78]

# %%
fruits[4]
# Out:
# 'Grapes'

# %%
fruits[-5]
# Out:
# 'Lemon'

# %%
fruits[3:10:2]
# Out:
# ['Orange', 'Pineapple', 'Papaya', 'Pomegranate']

# %%
fruits[::-1]
# Out:
# ['Peach',
#  'Grapefruit',
#  'Sweet Lime',
#  'Lime',
#  'Lemon',
#  'Pomegranate',
#  'Guava',
#  'Papaya',
#  'Watermelon',
#  'Pineapple',
#  'Grapes',
#  'Orange',
#  'Mango',
#  'Banana',
#  'Apple']

# %%
fruits+ my_list
# Out:
# ['Apple',
#  'Banana',
#  'Mango',
#  'Orange',
#  'Grapes',
#  'Pineapple',
#  'Watermelon',
#  'Papaya',
#  'Guava',
#  'Pomegranate',
#  'Lemon',
#  'Lime',
#  'Sweet Lime',
#  'Grapefruit',
#  'Peach',
#  11,
#  12,
#  24,
#  44,
#  45,
#  67,
#  78]

# %%
my_list*2
# Out:
# [78, 67, 45, 44, 24, 12, 11, 78, 67, 45, 44, 24, 12, 11]

# %%
my_list
# Out:
# [78, 67, 45, 44, 24, 12, 11]

# %%
l1=my_list.copy()

# %%
l1.count(67)
# Out:
# 1

# %%
l1.append(99)

# %%
l1
# Out:
# [11, 12, 24, 44, 45, 67, 78, 99]

# %%
l1.append([38,37])  # adds a single element which can be String, integer, touple or another list to the end of the list.

# %%
l1
# Out:
# [11, 12, 24, 44, 45, 67, 78, 99, [38, 37]]

# %%
l1.extend([38, 37])  # add the element in the end of the list

# %%
l1
# Out:
# [11, 12, 24, 44, 45, 67, 78, 99, [38, 37], 38, 37]

# %%
l1.insert(2,45)   #insert the element on the index number without replaceing it

# %%
l1
# Out:
# [11, 12, 45, 24, 44, 45, 67, 78, 99, [38, 37], 38, 37, 45]

# %%
l1.index(45)
# Out:
# 2

# %%
l1.pop()
# Out:
# 37

# %%
l1.remove(11)

# %%
l1
# Out:
# [12, 24, 44, 45, 67, 78, 99, [38, 37], 38]

# %% [markdown]
# l1.reverse()

# %%
l1
# Out:
# [38, [38, 37], 99, 78, 67, 45, 44, 24, 12]

# %%
l1.sort()    #'<' not supported between instances of 'list' and 'int'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %% [markdown]
# so for sorting or to use sort() function on list and int we have to do a type casting on it.

# %%
my_list.sort(reverse =True)

# %%
my_list
# Out:
# [78, 67, 45, 44, 24, 12, 11]

# %% [markdown]
# Tuple

# %%
t1 = (38, 28 , 64,76, 52, 41, 42, 66, 45)

# %%
t1[5]
# Out:
# 41

# %%
t1[-4]
# Out:
# 41

# %%
t1[:8]
# Out:
# (38, 28, 64, 76, 52, 41, 42, 66)

# %%
t1[::-1]
# Out:
# (45, 66, 42, 41, 52, 76, 64, 28, 38)

# %%
t1+t1
# Out:
# (38, 28, 64, 76, 52, 41, 42, 66, 45, 38, 28, 64, 76, 52, 41, 42, 66, 45)

# %%
t1*3
# Out:
# (38,
#  28,
#  64,
#  76,
#  52,
#  41,
#  42,
#  66,
#  45,
#  38,
#  28,
#  64,
#  76,
#  52,
#  41,
#  42,
#  66,
#  45,
#  38,
#  28,
#  64,
#  76,
#  52,
#  41,
#  42,
#  66,
#  45)

# %%
t1[2]=68
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 t1[2]=68
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1.count(42)
# Out:
# 1

# %%
t1.index(28)
# Out:
# 1

# %%
my_list + t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 my_list + t1
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
t1
# Out:
# (38, 28, 64, 76, 52, 41, 42, 66, 45)

# %%
t2=(38, 28, 64, 76)

# %%
t2
# Out:
# (38, 28, 64, 76)

# %%
a ,b, c, d = t2

# %%
a
# Out:
# 38

# %%
b
# Out:
# 28

# %%
c
# Out:
# 64

# %%
d
# Out:
# 76

# %%
t1
# Out:
# (38, 28, 64, 76, 52, 41, 42, 66, 45)

# %%
66 in t1
# Out:
# True

# %%
t1 is t2
# Out:
# False

# %%
l1 = [12, 24, 44, 45, 67, 78, 99, [38, 37], 38]

# %%
l1.append("45")

# %% [markdown]
# #

# %%
l1
# Out:
# [12, 24, 44, 45, 67, 78, 99, [38, 37], 38, '45']

# %%
list(t1)
# Out:
# [38, 28, 64, 76, 52, 41, 42, 66, 45]

# %%
len
