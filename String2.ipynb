# %% [markdown]
# Slicing
#
# Accessing part of a string
#
# str[ starting_idx : ending_idx]

# %%
str1= "this is my first string"

# %%
str1
# Out:
# 'this is my first string'

# %%
print(str1[4:len(str1)])
# Out:
#  is my first string

# %%
negative index

# %%
str = "apple"
print(str[-3:-1])
# Out:
# pl

# %%
str2= "i am studying python from youtube"
print(str.endswith("e"))
# Out:
# True

# %%
str2
# Out:
# 'i am studying python from youtube'

# %%
str2.capitalize()
# Out:
# 'I am studying python from youtube'

# %%
str2.replace("u","z")
# Out:
# 'i am stzdying python from yoztzbe'

# %%
str2.find("from")
# Out:
# 21

# %%
str2.count("o")
# Out:
# 3

# %% [raw]
# practice quetion
# 1. WAP to input user's  first name and its length
# 2. WAP to find the occurence of "$" in a String

# %%
#1que

name = input("enter your name:" )
print ("length of your name in",len(name))
# Out:
# enter your name: devil
# length of your name in 5

# %%
str4= "hey i $am the $ symbol $88.98"
print(str4.count("$"))
# Out:
# 3

# %% [markdown]
# # *Conditional Statements*
#
#
# if-elif-else(SYNTAX)
#
# if(condition):
#     Statement1
# elif(condition):
#     Statement2
# else:
#      statementN

# %%
age = 23

if(age>=18):
    print("can vote and apply for license")
    print("can drive and vote")
# Out:
# can vote and apply for license
# can drive and vote

# %%
light = "green"

if(light== "red"):
    print("stop")
  elif(light == "green"):
    print("go")
  elif(light == "yello"):
    print("look or wait")

print("end of the code")
# Out:
# go
# end of the code

# %%
light = "blue"

if(light == "red"):
     print("stop")
elif(light =="green"):
     print("go")
elif(light == "yello"):
     print("look or wait")
else:
    print("light is broken")
# Out:
# light is broken

# %%
age = 12

if(age >= 18):
    print("can vote")
else:
    print("can not vote")
# Out:
# can not vote

# %%
marks=  int(input("enter your marks"))
if(marks >= 90):
   print("grade = 'A'")
elif(marks >= 80 and marks < 90):
  print("grade = 'B'")
elif(marks >=70 and marks < 80):
   print("grade = 'C'")
else:
    print("above candidate is failed in exam")
# Out:
# enter your marks 909
# grade = 'A'
